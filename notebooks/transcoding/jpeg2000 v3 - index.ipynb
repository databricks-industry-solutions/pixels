# %% [markdown]
# # Overview
# Index the compressed file with Pixels in prep for display
#
# ## Requirements
# $./requirements.txt
#
# Compute: Serverless CPU Notebooks

# %%
import os
import dbx

repo_main_folder = os.path.abspath(os.path.join(os.path.dirname(dbx.__file__), os.pardir))
print(f"Installing Pixels Solution Accelerator dependencies from  {repo_main_folder}/requirements.txt")

# %pip install \
    numpy==1.26.4 \
    pydicom==3.0.1 \
    pylibjpeg \
    pylibjpeg-libjpeg \
    pylibjpeg-openjpeg

dbutils.library.restartPython()

# %%
import yaml
import pprint
compression = "nvImage_HTJ2K"
cfg = yaml.safe_load(open("config.yaml", "r"))
input_path = cfg.get("input_path")
output_path = cfg.get("output_path").replace("{compression}", f"{compression}")
table = cfg.get("table")
volume = cfg.get("volume")
write_mode = cfg.get("write_mode")

pprint.pprint(cfg, indent=4)
print(output_path)

# %%
import os
if not os.path.exists(output_path):
  print(f"Removing {output_path}")
  dbutils.notebook.exit(f"Path {output_path} does not exist. Nothing to index.")

# %%
import os
os.environ["PYLIBJPEG_OPENJPEG"] = "1"
import pydicom
import pylibjpeg # very important import

# %%
spark.sql(f"DROP TABLE IF EXISTS `{table}`")

# %%
def escape_table(table: str) -> str:
    parts = table.split('.')
    return f"`{parts[0]}`.`{parts[1]}`.{parts[2]}"

escape_table(table)

# %%
from dbx.pixels import Catalog
from dbx.pixels.dicom import DicomMetaExtractor # The Dicom transformers

if os.path.exists(output_path):
    catalog = Catalog(
        spark,
        table=escape_table(table),
        volume=volume)

    catalog_df = catalog.catalog(path=output_path)
    meta_df = DicomMetaExtractor(catalog, deep=False).transform(catalog_df)
    catalog.save(meta_df, mode=write_mode)

# %%
display(spark.table(escape_table(table)))

# %%
# %fs ls /Volumes/vdm-classic-q6xfh3_catalog/alpha/pixels_volume/20250227134948_CT_ISRA_0_nvImage_HTJ2K.dcm
