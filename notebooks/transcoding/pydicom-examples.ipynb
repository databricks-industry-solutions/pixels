# %% [markdown]
# %pip install pydicom==3.0.1

# %%
from pydicom import examples

img = examples.ybr_color
print(img)

# %%
print(img.file_meta.TransferSyntaxUID)

# %%
print(getattr(img, 'NumberOfFrames', None))

# %%
img.save_as("/Volumes/hls_radiology/demo/random/pydicom-examples-ybr_color-multi-frame.dcm")
