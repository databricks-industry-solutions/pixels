# %%
import sys
import os

sys.path.append(os.path.abspath(os.path.join(os.getcwd(), "../../dbx/pixels")))

# %%
from dbx.pixels.databricks_file import DatabricksFile

db_file = DatabricksFile.from_full_path(url.path.replace("api/2.0/fs/files", ""))

# %%
# %sh ls ../../dbx/pixels
