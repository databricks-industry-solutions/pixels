# %%
# %pip install pydicom

# %%
# %sh
export CLIENT_ID=""
export CLIENT_SECRET=""

python ./benchmark_stow_throughput.py \
    --sizes 5,10,50,100,250,500 \
    --repeats 3 \
    --concurrency 20 \
    --output results.json \
    --client-id $CLIENT_ID \
    --client-secret $CLIENT_SECRET \
    --databricks-host https://e2-demo-field-eng.cloud.databricks.com/ \
    --app-host https://pixels-dicomweb-gateway-1444828305810485.aws.databricksapps.com
